# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,HistGradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
data=pd.DataFrame({
    "EngineSize":[1.0,1.2,1.4,1.6,1.8, np.nan,2.0,2.2,2.4,2.6],
    "HorsePower":[68,75,90,100,110,115,np.nan,130,150,160],
    "FuelType":["Petrol","Diesel","Petrol","Diesel","Petrol",
                "Petrol",np.nan,"Diesel","Petrol","Diesel"],
    "FuelEfficiency":[20,22,19,25,18,21,23,26,17,24]
})

# %%
x=data[["EngineSize","HorsePower","FuelType"]]
y=data["FuelEfficiency"]
data
# Out:
#    EngineSize  HorsePower FuelType  FuelEfficiency
# 0         1.0        68.0   Petrol              20
# 1         1.2        75.0   Diesel              22
# 2         1.4        90.0   Petrol              19
# 3         1.6       100.0   Diesel              25
# 4         1.8       110.0   Petrol              18
# 5         NaN       115.0   Petrol              21
# 6         2.0         NaN      NaN              23
# 7         2.2       130.0   Diesel              26
# 8         2.4       150.0   Petrol              17
# 9         2.6       160.0   Diesel              24

# %%
num_cols=["EngineSize","HorsePower"]
cat_cols=["FuelType"]

# %%
numeric=Pipeline([
    ("imputer",SimpleImputer(strategy="median")),
    ("scaler",StandardScaler())
])
categorical=Pipeline([
    ("imputer",SimpleImputer(strategy="most_frequent")),
    ("OneHot"OneHotEncoder(handle_unknown="ignore"))
])
# Out:
#   File "/tmp/ipython-input-3962235453.py", line 7
#     ("OneHot"OneHotEncoder(handle_unknown="ignore"))
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
preprocess=ColumnTransformer([("num",numeric,num_cols),("cat",categorical,cat_cols)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3020329904.py in <cell line: 0>()
# ----> 1 preprocess=ColumnTransformer([("num",numeric,num_cols),("cat",categorical,cat_cols)])
#
# NameError: name 'ColumnTransformer' is not defined

# %%
model=Pipeline([
 ("Preprocess",preprocess),
 ("regressor",GradientBoostingRegressor(n_estimators=100,random_state=42,max_depth=3,learning_rate=0.1))
 ("model",Random)
  #SVR(kernel='rbf',C=100,gamma=0.1))
 ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1425139074.py in <cell line: 0>()
#       1 model=Pipeline([
# ----> 2  ("Preprocess",preprocess),
#       3  ("regressor",SVR(kernel='rbf',C=100,gamma=0.1))
#       4  ])
#
# NameError: name 'preprocess' is not defined

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_split=0.2,random_state=42)
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3882033777.py in <cell line: 0>()
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_split=0.2,random_state=42)
#       2 model.fit(x_train,y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     192
#     193             # Map *args/**kwargs to the function signature
# --> 194             params = func_sig.bind(*args, **kwargs)
#     195             params.apply_defaults()
#     196
#
# /usr/lib/python3.12/inspect.py in bind(self, *args, **kwargs)
#    3278         if the passed arguments can not be bound.
#    3279         """
# -> 3280         return self._bind(args, kwargs)
#    3281
#    3282     def bind_partial(self, /, *args, **kwargs):
#
# /usr/lib/python3.12/inspect.py in _bind(self, args, kwargs, partial)
#    3267                 )
#    3268             else:
# -> 3269                 raise TypeError(
#    3270                     'got an unexpected keyword argument {arg!r}'.format(
#    3271                         arg=next(iter(kwargs))))
#
# TypeError: got an unexpected keyword argument 'test_split'

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1579472061.py in <cell line: 0>()
# ----> 1 y_pred=model.predict(x_test)
#       2 print(y_pred)
#
# NameError: name 'model' is not defined

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print('MAE:',mae)
print("MSE:",mse)
print("RMSE:",rmse)
print("R2:",r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3131844822.py in <cell line: 0>()
# ----> 1 mae=mean_absolute_error(y_test,y_pred)
#       2 mse=mean_squared_error(y_test,y_pred)
#       3 rmse=np.sqrt(mse)
#       4 r2=r2_score(y_test,y_pred)
#       5 print('MAE:',mae)
#
# NameError: name 'y_test' is not defined
