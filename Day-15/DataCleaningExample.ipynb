# %%
import pandas as pd

# %%
data={'Students':['Amit','Anam','Chi','Sam','Ravi','Jai'],
      'Marks':[85,None,65,75,None,55]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#   Students  Marks
# 0     Amit   85.0
# 1     Anam    NaN
# 2      Chi   65.0
# 3      Sam   75.0
# 4     Ravi    NaN
# 5      Jai   55.0

# %%
print('Missing Data')
print('Number of Missing values are:',df.isnull().sum())
# Out:
# Missing Data
# Number of Missing values are: Students    0
# Marks       2
# dtype: int64

# %%
average_marks=df['marks'].mean()
print(average_marks)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 average_marks=df['marks'].mean()
#       2 print(average_marks)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'marks'

# %%
df.fillna(average_marks, inplace=True)

# %%
print('after fillna() call')
df

# %%
# Let us see it, how we will use in our project

# %%
#fillna() example
students_data={'Name':['Amit','Anam','Chi','Sam','Ravi','Jai'],'Marks':[85,None,65,75,None,55]}
df=pd.DataFrame(students_data)
df

# %%
df.fillna(df['Marks'].mean(), inplace=True)

# %%
df

# %% [markdown]
# # dropna() example

# %%
students_data={'Name':['Amit','Anam','Chi','Sam','Ravi','Jai'],'Marks':[85,None,65,75,None,55]}
df=pd.DataFrame(students_data)
print('Original Data')
df
# Out:
# Original Data
#    Name  Marks
# 0  Amit   85.0
# 1  Anam    NaN
# 2   Chi   65.0
# 3   Sam   75.0
# 4  Ravi    NaN
# 5   Jai   55.0

# %%
df=df.dropna(subset=['Marks'])

# %%
print('Dataset after dropna()')
df
# Out:
# Dataset after dropna()
#    Name  Marks
# 0  Amit   85.0
# 2   Chi   65.0
# 3   Sam   75.0
# 5   Jai   55.0

# %%
df=df.dropna()
print('Dataset after dropna()')
df
# Out:
# Dataset after dropna()
#    Name  Marks
# 0  Amit   85.0
# 2   Chi   65.0
# 3   Sam   75.0
# 5   Jai   55.0

# %%
emp_data={
    "Name":['Sam','Ali','Chang','Xi','Viz','Suhail'],
    "Age":[35,None,25,20,24,None],
    "Salay":[50000,30000,20000,40000,None,None],
}
df=pd.DataFrame(emp_data)
print('Original Data')
df
# Out:
# Original Data
#      Name   Age    Salay
# 0     Sam  35.0  50000.0
# 1     Ali   NaN  30000.0
# 2   Chang  25.0  20000.0
# 3      Xi  20.0  40000.0
# 4     Viz  24.0      NaN
# 5  Suhail   NaN      NaN

# %%
print(df.isnull().sum())
# Out:
# Name     0
# Age      2
# Salay    2
# dtype: int64

# %%
df_drop_salary=df.dropna(subset=['Salary'])
df_drop_salary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18948\575223069.py in ?()
# ----> 1 df_drop_salary=df.dropna(subset=['Salary'])
#       2 df_drop_salary
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['Salary']

# %%
df_fillna=df.fillna(df['Age'].mean(),inplace=True)
df_fillna=df.fillna(df['Salary'].mean(),inplace=True
# Out:
#   Cell In[41], line 2
#     df_fillna=df.fillna(df['Salary'].mean(),inplace=True
#                                                         ^
# _IncompleteInputError: incomplete input

# %%
emp_data={
    "Name":['Sam','Ali','Chang','Xi','Viz','Suhail'],
    "Age":[35,None,25,20,24,None],
    "Salay":[50000,30000,20000,40000,None,None],
    }
df=pd.DataFrame(emp_data)
df.fillna({'Age':df['Age'].mean(),'Salary':df['Salary'].mean()}, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 7
#       1 emp_data={
#       2     "Name":['Sam','Ali','Chang','Xi','Viz','Suhail'],
#       3     "Age":[35,None,25,20,24,None],
#       4     "Salay":[50000,30000,20000,40000,None,None],
#       5     }
#       6 df=pd.DataFrame(emp_data)
# ----> 7 df.fillna({'Age':df['Age'].mean(),'Salary':df['Salary'].mean()}, inplace=True)
#       8 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Salary'

# %%
df.fillna({'Age':df['Age'].mean(),'Salary':df['Salary'].mean(), inplace=True)
# Out:
#   Cell In[27], line 1
#     df.fillna({'Age':df['Age'].mean(),'Salary':df['Salary'].mean(), inplace=True)
#                                                                                 ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '{'

# %%
df
# Out:
#      Name   Age    Salay
# 0     Sam  35.0  50000.0
# 1     Ali   NaN  30000.0
# 2   Chang  25.0  20000.0
# 3      Xi  20.0  40000.0
# 4     Viz  24.0      NaN
# 5  Suhail   NaN      NaN

# %%
student_data=pd.read_csv('student.csv)
# Out:
#   Cell In[43], line 1
#     student_data=pd.read_csv('student.csv)
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Download students_performance_dirty.csv
# ## find out number of missing data
# ## drop rows where gender is missing
# ## fill study_hours with average study_hours

# %%
df=pd.read_csv('students_performance_dirty.csv')
df.head(5)
# Out:
#    gender  study_hours  attendance_pct  math_score  reading_score  final_score
# 0    male          1.7            83.6        62.0           91.0         38.9
# 1     NaN          2.6            91.2        82.0           60.0         37.5
# 2  female          2.9            97.5        69.0           57.0         35.0
# 3  female          4.8            85.7        78.0           62.0         36.5
# 4    male          3.9           -10.0        64.0           95.0         30.9

# %%
# Solution for Question Number 1
print('Number of Missing values are:',df.isnull().sum())
# Out:
# Number of Missing values are: gender            8
# study_hours       8
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64

# %%
# Solution Q 2: drop rows where gender is missing
df_deleted_gender=df.dropna(subset=['gender'])

# %%
# Solution Q 3: fill study_hours with average_study_hours
df_deleted_gender.fillna({'study_hours':df['study_hours'].mean()}, inplace=True)
# Out:
# C:\Users\sabri\AppData\Local\Temp\ipykernel_18948\3620016615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_deleted_gender.fillna({'study_hours':df['study_hours'].mean()}, inplace=True)

# %%
print('Number of Missing value are:',df_deleted_gender.isnull().sum())
# Out:
# Number of Missing value are: gender            0
# study_hours       0
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64

# %%
df
# Out:
#     gender  study_hours  attendance_pct  math_score  reading_score  \
# 0     male          1.7            83.6        62.0           91.0
# 1      NaN          2.6            91.2        82.0           60.0
# 2   female          2.9            97.5        69.0           57.0
# 3   female          4.8            85.7        78.0           62.0
# 4     male          3.9           -10.0        64.0           95.0
# 5     male          1.4            93.7        77.0           72.0
# 6     male          NaN            87.1        95.0           78.0
# 7    femle          NaN            70.6        59.0           70.0
# 8   female          2.7            74.7        68.0           71.0
# 9   female          4.2            92.4        63.0           66.0
# 10    male          4.7            67.9        94.0           73.0
# 11     NaN          4.6            86.2        63.0           78.0
# 12   femle          NaN            95.0        59.0           92.0
# 13    male          NaN            86.5        61.0           50.0
# 14    male          3.9            79.0        68.0           91.0
# 15    male          4.7            76.5        58.0           78.0
# 16    male          2.9            93.2        64.0           68.0
# 17  female          3.3            89.7        72.0           65.0
# 18  female          2.2           150.0        68.0           85.0
# 19    male          2.1            95.7        82.0           75.0
# 20  female          NaN            93.5        65.0           54.0
# 21    male          5.1           102.9        67.0           76.0
# 22    male          3.4            90.7        74.0           86.0
# 23    male          4.7            83.4       104.0           82.0
# 24  female          3.9            83.6        58.0           64.0
# 25  female          2.7            65.7        99.0           56.0
# 26    male          3.9            86.5        52.0           68.0
# 27  female          5.3            84.8        73.0          111.0
# 28  female          NaN            71.7        65.0           53.0
# 29    male          5.4            84.7        58.0           62.0
# 30  female          0.4            98.4        80.0           77.0
# 31    male          4.5            77.7        79.0           71.0
# 32    male          3.6            75.4        63.0           70.0
# 33     NaN          NaN            96.0        39.0           96.0
# 34     NaN          3.6            91.3        64.0           62.0
# 35   femle          1.1           115.6        72.0           72.0
# 36    male          3.2            71.8        70.0           74.0
# 37    male          3.9            92.2        81.0           62.0
# 38  female          5.3            88.2        99.0           55.0
# 39  female          2.9            85.6        76.0           75.0
# 40    male          2.5            94.1        79.0           94.0
# 41  female          2.9            84.7        72.0           77.0
# 42    male          4.6            65.6        88.0           73.0
# 43     NaN          3.9            76.5        78.0           73.0
# 44    male          2.9           200.0        81.0           69.0
# 45  female          4.1            96.7        97.0           86.0
# 46    male          3.6            81.3        73.0           66.0
# 47  female          4.7            90.0        66.0           56.0
# 48  female          2.7           112.8        77.0           53.0
# 49    male          3.1            84.7        87.0           73.0
# 50     NaN          3.0            84.9        78.0           85.0
# 51  female          1.7            86.9        86.0           75.0
# 52     NaN          3.9            91.1        60.0           68.0
# 53   femle          3.8            81.5        57.0           78.0
# 54  female          3.5            91.1        62.0           74.0
# 55     NaN          3.2           300.0        51.0           82.0
# 56    male          1.8            88.4        72.0           88.0
# 57    male          3.0            85.5        64.0           61.0
# 58    male          3.1            82.8        88.0           44.0
# 59    male          NaN            80.2        51.0           68.0
#
#     final_score
# 0          38.9
# 1          37.5
# 2          35.0
# 3          36.5
# 4          30.9
# 5          39.0
# 6          43.4
# 7          32.8
# 8          35.3
# 9          35.0
# 10         40.1
# 11         36.9
# 12         39.7
# 13         30.8
# 14         39.8
# 15         34.9
# 16         35.7
# 17         36.5
# 18         45.6
# 19         41.0
# 20         33.1
# 21         38.9
# 22         41.0
# 23         45.5
# 24         32.9
# 25         37.5
# 26         32.7
# 27         45.4
# 28         30.8
# 29         32.4
# 30         41.3
# 31         37.7
# 32         34.0
# 33         36.6
# 34         34.2
# 35         40.3
# 36         36.1
# 37         38.0
# 38         39.6
# 39         38.8
# 40         43.9
# 41         38.3
# 42         38.7
# 43         37.8
# 44         50.0
# 45         46.3
# 46         36.0
# 47         33.3
# 48         37.2
# 49         40.5
# 50         40.9
# 51         40.8
# 52         34.7
# 53         35.0
# 54         36.3
# 55         56.6
# 56         40.8
# 57         33.4
# 58         34.8
# 59         31.7

# %%
print('Number of Missing value are:',df.isnull().sum())
# Out:
# Number of Missing value are: gender            8
# study_hours       8
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64
