# %% [markdown]
# # 2. Logistic Regression - Pass/Fail

# %%
#import the data
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
#collect the data
df=pd.read_csv('pass_fail.csv')
df.head()
# Out:
#    Hours Result
# 0      1   Fail
# 1      2   Fail
# 2      3   Fail
# 3      4   Pass
# 4      5   Pass

# %%
#split the data
x=df[['Hours']]
y=df['Result']

# %%
#creating the model
model=LogisticRegression()

# %%
#trained the model
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
pred_35=model.predict([[3.5]])
print('Predicted result for 3.5 hours:', pred_35[0])
# Out:
# Predicted result for 3.5 hours: Pass
# C:\Users\sabri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
hours_study=float(input('Number hours studied'))
pred_value=model.predict([[hours_study]])
print(f'After {hours_study} hours study you likely to {pred_value[0]}')
# Out:
# Number hours studied 3
# After 3.0 hours study you likely to Fail
# C:\Users\sabri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('customer_purchase.csv')
df.head()
# Out:
#    Age  Salary Purchased
# 0   22   25000        No
# 1   25   30000        No
# 2   30   40000       Yes
# 3   35   50000       Yes
# 4   40   60000       Yes

# %%
le=LabelEncoder()
df['Purchased']=le.fit_transform(df['Purchased'])
x=df[['Age','Salary']]
y=df['Purchased']

# %%
df
# Out:
#    Age  Salary  Purchased
# 0   22   25000          0
# 1   25   30000          0
# 2   30   40000          1
# 3   35   50000          1
# 4   40   60000          1

# %%
model=LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
new_customer=[[28,3500]]
prediction=model.predict(new_customer)
print(f'Predicted Result (1=Yes, 0=No): {prediction[0]}')
# Out:
# Predicted Result (1=Yes, 0=No): 0
# C:\Users\sabri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
new_cust_age=int(input("Enter Age"))
new_cust_sal=int(input("Enter Salary"))
new_cust=[[new_cust_age,new_cust_sal]]
prediction=model.predict(new_cust)
if (prediction):
    print('likely Purchased')
else:
    print('likely Not Purchased')
# Out:
# Enter Age 87
# Enter Salary 4000
# C:\Users\sabri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 4
#       2 new_cust_sal=int(input("Enter Salary"))
#       3 new_cust=[[new_cust_age,new_cust_sal]]
# ----> 4 prediction=model.predict(new_cust)
#       5 if (prediction):
#       6     print('likely Purchased')
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:374, in LinearClassifierMixin.predict(self, X)
#     360 """
#     361 Predict class labels for samples in X.
#     362
#    (...)
#     371     Vector containing the class labels for each sample.
#     372 """
#     373 xp, _ = get_namespace(X)
# --> 374 scores = self.decision_function(X)
#     375 if len(scores.shape) == 1:
#     376     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:352, in LinearClassifierMixin.decision_function(self, X)
#     349 xp, _ = get_namespace(X)
#     351 X = validate_data(self, X, accept_sparse="csr", reset=False)
# --> 352 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     353 return (
#     354     xp.reshape(scores, (-1,))
#     355     if (scores.ndim > 1 and scores.shape[1] == 1)
#     356     else scores
#     357 )
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'

# %% [markdown]
# # Logistic Regression Spam/NoSpam
# ## Download spam_data.csv from kaggle.com
# ## load the data
# ## Do the data cleaning and labelling (if required)
# ## Use Logistic Regression Algorithm to trained the Model
# ## Predict Result if the email is spam or not spam

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %%
# cv=CountVectorizer
# x=df['Message']

# %%
# x_data=cv.fit_transform(x)

# %%
df=pd.read_csv('spam_dataset.csv')
df.head()
# Out:
#                                      message_content  is_spam
# 0  Hello Lonnie,\n\nJust wanted to touch base reg...        0
# 1  Congratulations, you've won a prize! Call us n...        1
# 2  You have been pre-approved for a credit card w...        1
# 3  Limited time offer, act now! Only a few spots ...        1
# 4  Your loan has been approved! Transfer funds to...        1

# %%
x=df['message_content']
y=df['is_spam']

# %%
# Extra steps here: convert text to numbers
cv=CountVectorizer()
x_cv=cv.fit_transform(x)

# %%
model=LogisticRegression()

# %%
model.fit(x_cv,y)
# Out:
# LogisticRegression()

# %%
# Step 8: Try custom messages
sample= ["Win a free iPhone now!", "Are you coming to class today?"]
pred=model.predict(cv.transform(sample))
if(pred[0]):
    print('Not Spam')
else:
    print('SPAM')
#for msg, Label in zip (sample, pred):
#print(msg,"->", "SPAM" if label == 1 else "NOT SPAM")
# Out:
# Not Spam

# %% [markdown]
# ### answer from chatgpt

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# 1️⃣ Load dataset
df = pd.read_csv('spam_dataset.csv')

# 2️⃣ Split features (X) and labels (y)
X = df['message_content']
y = df['is_spam']

# 3️⃣ Convert text into numerical features
cv = CountVectorizer()
X_data = cv.fit_transform(X)

# 4️⃣ Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.2, random_state=42)

# 5️⃣ Train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# 6️⃣ Check accuracy
accuracy = model.score(X_test, y_test)
print(f"Model accuracy: {accuracy:.2f}")

# 7️⃣ Predict a new message
sample = ["Congratulations! You've won a free ticket!"]
sample_data = cv.transform(sample)
prediction = model.predict(sample_data)

print("Predicted result:", "Spam" if prediction[0] == 1 else "Not Spam")
# Out:
# Model accuracy: 1.00
# Predicted result: Spam
